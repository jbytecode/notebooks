# %%
using Pkg; Pkg.activate(".")
# Out:
#   Activating project at `~/code/julia/notebooks`

# %%
using OperationsResearchModels, Ipopt, Statistics, JuMP

# %%
mydata = rand(30, 3);

# %%
means = mean(mydata, dims = 1)
# Out:
# 1×3 Matrix{Float64}:
#  0.477887  0.529508  0.469411

# %%
covmat = cov(mydata)
# Out:
# 3×3 Matrix{Float64}:
#  0.0982385   0.0116726   0.0141985
#  0.0116726   0.081138   -0.0415484
#  0.0141985  -0.0415484   0.0791528

# %%
problem = PortfolioProblem(mydata, 0.40)
# Out:
# PortfolioProblem([0.7964075728103254 0.29280899112064995 0.6969471360917232; 0.09081478268004262 0.14816379081377662 0.6397761295086459; … ; 0.8099783646525079 0.6779212190574726 0.28647097991126125; 0.7047676703578771 0.3653786116839146 0.4887135848662879], 0.4)

# %%
result = solve(problem)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
# PortfolioResult([0.06929729528398022, 0.46227492862100794, 0.46842777609501185], 0.4977798298746803, A JuMP Model
# ├ solver: Ipopt
# ├ objective_sense: MIN_SENSE
# │ └ objective_function_type: JuMP.QuadExpr
# ├ num_variables: 3
# ├ num_constraints: 8
# │ ├ JuMP.AffExpr in MOI.EqualTo{Float64}: 1
# │ ├ JuMP.AffExpr in MOI.GreaterThan{Float64}: 1
# │ ├ JuMP.VariableRef in MOI.GreaterThan{Float64}: 3
# │ └ JuMP.VariableRef in MOI.LessThan{Float64}: 3
# └ Names registered in the model
#   └ :w)

# %%
println(result.model)
# Out:
# Min 0.09823848828712521 w[1]² + 0.023345101542386483 w[2]*w[1] + 0.028396941284330915 w[3]*w[1] + 0.081138018655197 w[2]² - 0.08309672286246783 w[3]*w[2] + 0.07915284538303226 w[3]²
# Subject to
#  w[1] + w[2] + w[3] = 1
#  0.4778868007974609 w[1] + 0.5295082706329425 w[2] + 0.4694110390922367 w[3] ≥ 0.4
#  w[1] ≥ 0
#  w[2] ≥ 0
#  w[3] ≥ 0
#  w[1] ≤ 1
#  w[2] ≤ 1
#  w[3] ≤ 1

# %%
JuMP.latex_formulation(result.model)
# Out:
# $$ \begin{aligned}
# \min\quad & 0.09823848828712521 w_{1}^2 + 0.023345101542386483 w_{2}\times w_{1} + 0.028396941284330915 w_{3}\times w_{1} + 0.081138018655197 w_{2}^2 - 0.08309672286246783 w_{3}\times w_{2} + 0.07915284538303226 w_{3}^2\\
# \text{Subject to} \quad & w_{1} + w_{2} + w_{3} = 1\\
#  & 0.4778868007974609 w_{1} + 0.5295082706329425 w_{2} + 0.4694110390922367 w_{3} \geq 0.4\\
#  & w_{1} \geq 0\\
#  & w_{2} \geq 0\\
#  & w_{3} \geq 0\\
#  & w_{1} \leq 1\\
#  & w_{2} \leq 1\\
#  & w_{3} \leq 1\\
# \end{aligned} $$
