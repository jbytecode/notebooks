# %%
# İkili (binary) ve tekli (unary) operatörler:
# Örneğin negate (-) operatörü tek operand alırken
# (+) operatörü iki operand alır:
a <- -1
b <- a + 10
cat(a, b)
# Out:
# -1 9

# %%
# (+) operatörü iki sayısal değeri toplarken, uygun durumda
# tip dönüşümü gerçekleştirilir. Örneğin mantıksal (logical) 
# TRUE değeri 1 ile işlem görebilir:
a <- TRUE
b <- 9
c <- a + b
print(c)
# Out:
# [1] 10

# %%
TRUE + TRUE
# Out:
# [1] 2

# %%
as.integer(TRUE)
# Out:
# [1] 1

# %%
as.double(TRUE)
# Out:
# [1] 1

# %%
as.numeric(TRUE)
# Out:
# [1] 1

# %%
as.complex(TRUE)
# Out:
# [1] 1+0i

# %%
# as.xxx ve is.xxx fonksiyonları tip dönüşümleri ve tip kontrolleri için kullanılır:
is.numeric(5)
# Out:
# [1] TRUE

# %%
is.double(3.141592)
# Out:
# [1] TRUE

# %%
is.integer(1234L)
# Out:
# [1] TRUE

# %%
is.integer(FALSE)
# Out:
# [1] FALSE

# %%
is.integer(TRUE)
# Out:
# [1] FALSE

# %%
is.double("Merhaba")
# Out:
# [1] FALSE

# %%
is.character("Merhaba R!")
# Out:
# [1] TRUE

# %%
# Fonksiyonlar, adlarını takiben parantezlerle kullanılır. 
# R'de bir fonksiyon hiç bir argüman almayabilir.
# Bir veya birden fazla argüman alabilir.
# Bir değer döndürebilir veya döndürmeyebilir.
# Örneğin sqrt() (Square Root) fonksiyonu verilen bir argümanın
# karekökünü döndürür ve şöyle kullanılır:
sqrt(25)
# Out:
# [1] 5

# %%
sqrt(2 * pi)
# Out:
# [1] 2.506628

# %%
# logaritma
# 100'ün logaritması:
log(100)
# Out:
# [1] 4.60517

# %%
# Varsayılan taban 10 değil e'dir. 
# R, varsayılan olarak doğal logaritma hesaplar:
# taban için ikinci bir argüman kullanılabilir:
log(x = 100, base = 10)
# Out:
# [1] 2

# %%
# Argüman isimleri, argüman sırası unutulduysa ve okunabilirliği artırması için kullanılabilir.
log(100, base = 10)
# Out:
# [1] 2

# %%
log(100, 10)
# Out:
# [1] 2

# %%
# exp() fonksiyonu e^x değerini hesaplar (üstel fonksiyon - exponential function)
exp(1)
# Out:
# [1] 2.718282

# %%
exp(2)
# Out:
# [1] 7.389056

# %%
# Bileşke fonksiyonlar f(g(x)) ya da (f o g)(x) kullanım biçimi R için de geçerlidir:
# Aşağıdaki örnekte önce e^1 hesaplanır. Oluşan değer logaritma fonksiyonunun argümanı olur:
log(exp(1))
# Out:
# [1] 1

# %%
# Fonksiyonların tanım aralıklarına uyulmazsa hata alınır:
sqrt(-5)
# Out:
# Warning message in sqrt(-5):
# “NaNs üretimi”
# [1] NaN

# %%
# NaN -> Not a Number
sqrt(log(0.5))
# Out:
# Warning message in sqrt(log(0.5)):
# “NaNs üretimi”
# [1] NaN

# %%
# Tam sayıya yuvarlama için floor, ceiling ve round kullanılabilir:
ceiling(4.5)
# Out:
# [1] 5

# %%
floor(4.5)
# Out:
# [1] 4

# %%
round(3.4)
# Out:
# [1] 3

# %%
round(3.6)
# Out:
# [1] 4

# %%
# Trigonometrik fonksiyonlar
sin(x = pi / 2)
# Out:
# [1] 1

# %%
cos(0)
# Out:
# [1] 1

# %%
tan(0)
# Out:
# [1] 0

# %%
# Kotanjant için bir fonksiyon bulunmamaktadır. 
# Ancak sin, cos veya tan varken bu fonksiyonu biz de tanımlayabiliriz.
# Bu konu sonraki notlarda yer bulacaktır.
cot(pi/2)
# Out:
# Error in cot(pi/2): "cot" fonksiyonu bulunamadı
# Traceback:

# %%
# Şimdilik cot(x) = 1 / tan(x) için şunu kullanabiliriz:
mycot <- 1.0 / tan(0)
print(mycot)
# Out:
# [1] Inf

# %%
# Inf değeri sonsuzluk gösterir. Değeri şöyle kontrol edilir:
is.infinite(mycot)
# Out:
# [1] TRUE

# %%
is.infinite(Inf)
# Out:
# [1] TRUE

# %%
# Sonsuz, çok büyük olana hala çok uzaktır:
a <- 12345678912345678912345678123456
is.infinite(a)
# Out:
# [1] FALSE

# %%
b <- 10^32

# %%
print(b)
# Out:
# [1] 1e+32

# %%
# Xe+Y bilimsel notasyonunu şöyle okuyabilir:
# 1e+32 -> 1 x 10^32
# 4e+50 -> 4 x 10^50
# 6e+6  -> 6 x 10^6 -> 6 milyon
# 1e-3  -> 1 x 10^(-3) -> 1 / 1000
# 1e-50 -> 1 x 10^(-50) -> neredeyse sıfır
1e-50
# Out:
# [1] 1e-50

# %%
1e-50 == 0.0
# Out:
# [1] FALSE

# %%
# == operatörü iki değerin eşitliğini sınar. 
# <= operatörü ilk operandın ikinciden küçük veya eşit olmadığını sınar.
# >=, <, > operatörleri de benzer şekilde karşılaştırma işlemlerini gerçekleştirir.
# ==, <=, >=, <, > operatörleri iki operand alır ve daima TRUE veya FALSE döndürürler.
3 == 3
# Out:
# [1] TRUE

# %%
3 < 5
# Out:
# [1] TRUE

# %%
5 < 1
# Out:
# [1] FALSE

# %%
2 <= 2
# Out:
# [1] TRUE

# %%
5 >= 4
# Out:
# [1] TRUE

# %%
# != operatörü iki operand eşitse FALSE, değilse TRUE döndürür
6 != 4
# Out:
# [1] TRUE

# %%
4 != 4
# Out:
# [1] FALSE

# %%
# Özel NULL değeri, hiçlik için kullanılır. 
# Aşağıda sayi değişkenine hiçlik değeri atanır:
sayi <- NULL

# %%
# Bir değişkenin NULL olup olmadığı
# is.null() ile elde edilir:
is.null(sayi)
# Out:
# [1] TRUE

# %%
# Benzer şekilde NA, NaN sabitleri de var olmama durumunu ve sayı olmama durumlarını gösterir.
# NA -> Not Available
# NaN -> Not A Number
a <- NA
is.na(a)
# Out:
# [1] TRUE

# %%
b <- NaN
is.nan(b)
# Out:
# [1] TRUE

# %%
exists("a")
# Out:
# [1] TRUE

# %%
exists("z")
# Out:
# [1] FALSE

# %%
# exist() ile bir değişkenin var olup olmadığını sınayabiliriz.
# ls() fonksiyonu ile R ortamında o anda tanımlanmış değişkenlerin bir listesini alırız:
ls()
# Out:
# [1] "a"     "b"     "c"     "mycot" "sayi"

# %%
# Daha önce c() ile verilerin bir araya getirilip (combine) tek bir veri nesnesinin 
# oluşturulabildiğine değindik.
mynumbers <- c(1, 2, -9, 10, 0)
mynumbers
# Out:
# [1]  1  2 -9 10  0

# %%
# Benzer şekilde list() ile bir liste oluşturulur:
my.shopping.list <- list("apples", "oranges", "bananas")

# %%
my.shopping.list
# Out:
# [[1]]
# [1] "apples"
#
# [[2]]
# [1] "oranges"
#
# [[3]]
# [1] "bananas"

# %%
# Bu listenin eleman sayısı 3'tür:
length(my.shopping.list)
# Out:
# [1] 3

# %%
# Bu listenin ilk elemanı 'apples' olmalıdır:
my.shopping.list[[1]]
# Out:
# [1] "apples"

# %%
my.shopping.list[[2]]
# Out:
# [1] "oranges"

# %%
my.shopping.list[[3]]
# Out:
# [1] "bananas"

# %%
# Ayrıca liste elemanlarına indis yerine isimlerle erişilebilir.
# Aşağıdaki sepette hangi nesneden kaç kilo satın alınacağı belirtiliyor olsun:
sepet <- list(
    "elma" = 3, 
    "portakal" = 4,
    "muz" = 1
)

# %%
# Sepete göz gezdirelim:
sepet
# Out:
# $elma
# [1] 3
#
# $portakal
# [1] 4
#
# $muz
# [1] 1

# %%
# Bu listenin elemanlarına artık $ ifadesiyle başlayan isimleriyle erişebiliriz:
sepet["elma"]
# Out:
# $elma
# [1] 3

# %%
sepet["muz"]
# Out:
# $muz
# [1] 1

# %%
sepet["kavun"]
# Out:
# $<NA>
# NULL

# %%
# Listeye hala indislerle erişim mümkündür:
sepet[1]
# Out:
# $elma
# [1] 3

# %%
sepet[[1]]
# Out:
# [1] 3

# %%
# Sepete yeni eleman ekleyebiliriz:
sepet["kavun"] <- 3

# %%
sepet
# Out:
# $elma
# [1] 3
#
# $portakal
# [1] 4
#
# $muz
# [1] 1
#
# $kavun
# [1] 3
